# %%
x=[1,2,3,4]
y=[5,6,7,8]
plt.plot(x,y)
plt.show()

# %% [markdown]
# # color

# %%
import matplotlib.pyplot as plt
x=[2,4,6,8,10]
y=[3,5,7,9,11]
c=["r","y","g","b","skyblue"]
plt.bar(x,y,color=c)
plt.show()

# %% [markdown]
# # bar plot

# %%
import matplotlib.pyplot as plt

# %%
x=["python","c","c++","java"]
y=[90,60,40,85]
plt.bar(x,y,width=.4)
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("nikhil",fontsize=15)
plt.show()

# %%
x=["python","c","c++","java"]
y=[90,60,40,85]
c=["y","g","b","r"]
plt.bar(x,y,width=.4,color=c)
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.show()

# %% [markdown]
# # align parameter

# %%
x=["python","c","c++","java"]
y=[90,60,40,85]
c=["y","g","b","r"]
plt.bar(x,y,width=.4,color=c,align="edge")
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.show()

# %% [markdown]
# # to the change of bar graph bountery

# %%
x=["python","c","c++","java"]
y=[90,60,40,85]
c=["y","g","b","r"]
plt.bar(x,y,width=.4,color=c,align="edge",edgecolor="b",linewidth=5)
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.show()

# %% [markdown]
# # alpha parameter

# %%
x=["python","c","c++","java"]
y=[90,60,40,85]
c=["y","g","b","r"]
plt.bar(x,y,width=.4,color=c,align="edge",edgecolor="b",linewidth=5,alpha=.5)
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.show()

# %% [markdown]
# # label parameter

# %%
x=["python","c","c++","java"]
y=[90,60,40,85]
c=["y","g","b","r"]
plt.bar(x,y,width=.4,color=c,align="edge",edgecolor="b",linewidth=5,alpha=.5,label="nikhil")
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.legend()
plt.show()

# %% [markdown]
# # create multiple bar graph

# %%
x=["python","c","c++","java"]
y=[90,60,40,85]
z=[20,30,35,50]
c=["y","g","b","r"]
plt.bar(x,y,width=.4,color=c,align="edge",edgecolor="b",label="nikhil")
plt.bar(x,z,width=.4,color="pink",align="edge",edgecolor="black",label="populiity")
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=["python","c","c++","java"]
y=[90,60,40,85]
z=[20,30,35,50]
width=.4
p=np.arange(len(x))
p1=[j+width for j in p]
c=["y","g","b","r"]
plt.bar(p,y,width=.4,color=c,align="edge",edgecolor="b",label="nikhil")
plt.bar(p1,z,width=.4,color="pink",align="edge",edgecolor="black",label="populiity")
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.xticks(p+width,x,rotation=20)
plt.legend()
plt.show()

# %%
x=["python","c","c++","java"]
y=[90,60,40,85]
z=[20,30,35,50]
c=["y","g","b","r"]
plt.barh(x,y,color=c,align="edge",edgecolor="b",label="nikhil")
plt.barh(x,z,color="pink",align="edge",edgecolor="black",label="populiity")
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=["python","c","c++","java"]
y=[90,60,40,85]
z=[20,30,35,50]

p=np.arange(len(x))
p1=[j+width for j in p]
c=["y","g","b","r"]
plt.barh(p,y,color=c,align="edge",edgecolor="b",label="nikhil")
plt.bar(p1,z,color="pink",align="edge",edgecolor="black",label="populiity")
plt.xlabel("language",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.title("Bar graph",fontsize=15)
plt.xticks(p+width,x,rotation=20)
plt.legend()
plt.show()

# %% [markdown]
# # scatter plot

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[11,12,13,14,15,22,33]
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # for title

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[11,12,13,14,15,22,33]
colors=["red","green","yellow","black","purple","blue","skyblue"]
plt.scatter(x,y,c=colors)
plt.title("scatter plot",fontsize=16)
plt.xlabel("days",fontsize=16)
plt.ylabel("NO.",fontsize=16)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[11,12,13,14,15,22,33]
sizes=[300,200,190,106,170,180,190]
colors=["red","green","yellow","black","purple","blue","skyblue"]
plt.scatter(x,y,c=colors,s=sizes,alpha=.2)
plt.title("scatter plot",fontsize=16)
plt.xlabel("days",fontsize=16)
plt.ylabel("NO.",fontsize=16)
plt.show()

# %% [markdown]
# # marker parameter

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[11,12,13,14,15,22,33]
sizes=[300,200,190,106,170,180,190]
colors=["red","green","yellow","black","purple","blue","skyblue"]
plt.scatter(x,y,c=colors,s=sizes,marker="*")
plt.title("scatter plot",fontsize=16)
plt.xlabel("days",fontsize=16)
plt.ylabel("NO.",fontsize=16)
plt.show()

# %% [markdown]
# # marker edge color and line width

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[11,12,13,14,15,22,33]
sizes=[300,200,190,106,170,180,190]
colors=["red","green","yellow","black","purple","blue","skyblue"]
plt.scatter(x,y,c=colors,s=sizes,alpha=.2)
plt.title("scatter plot",fontsize=16)
plt.xlabel("days",fontsize=16)
plt.ylabel("NO.",fontsize=16)
plt.show()

# %% [markdown]
# # cmap parameter

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[11,12,13,14,15,22,33]
colors=[4,5,7,12,34,67,89]
sizes=[300,200,190,106,170,180,190]
plt.scatter(x,y,c=colors,s=sizes,cmap="Dark2")
t=plt.colorbar()
t.set_label("ColorBar",fontsize=16)
plt.title("scatter plot",fontsize=16)
plt.xlabel("days",fontsize=16)
plt.ylabel("NO.",fontsize=16)
plt.show()

# %% [markdown]
# # histrogram ep6

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [41 51 52 25 21 59 12 49 14 48 37 17 57 35 22 49 31 26 10 47 19 39 14 49
#  39 40 23 44 40 31 52 10 10 32 38 56 38 26 14 48 55 26 57 39 33 56 29 31
#  21 16]

# %%
plt.hist(x,color="r")
plt.show()

# %% [markdown]
# # for label

# %%
plt.hist(x,color="r",edgecolor="blue")
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # the set of bar

# %%
l=[10,20,30,40,50,60]
plt.hist(x,color="r",bins=l,edgecolor="blue")
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # given range perameter

# %%
l=[10,20,30,40,50,60]
plt.hist(x,"auto",(0,100),edgecolor="blue")
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # community parameter

# %%
l=[10,20,30,40,50,60]
plt.hist(x,"auto",(0,100),edgecolor="blue",cumulative=-1)
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # bottom parameter

# %%
l=[10,20,30,40,50,60]
plt.hist(x,"auto",(0,100),edgecolor="blue",bottom=30)
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # aligement parameter

# %%
l=[10,20,30,40,50,60]
plt.hist(x,color="r",bins=l,edgecolor="blue",align="mid")
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # hist type

# %%
l=[10,20,30,40,50,60]
plt.hist(x,color="r",bins=l,edgecolor="blue",histtype="barstacked")
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # orientation

# %%
l=[10,20,30,40,50,60]
plt.hist(x,color="r",bins=l,edgecolor="blue",orientation="horizontal")
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # less graph width

# %%
l=[10,20,30,40,50,60]
plt.hist(x,color="r",bins=l,edgecolor="blue",width=4)
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.show()

# %% [markdown]
# # label paraameter

# %%
l=[10,20,30,40,50,60]
plt.hist(x,color="r",bins=l,edgecolor="blue",label="python",width=6)
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.legend()
plt.show()

# %%
l=[10,20,30,40,50,60]
plt.hist(x,color="r",bins=l,edgecolor="blue",histtype="barstacked",label="python")
plt.axvline(30,color="y",label="line")
plt.title("nikhil",fontsize=15)
plt.xlabel("python",fontsize=15)
plt.ylabel("No.",fontsize=15)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # pie plot ep7

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
plt.pie(x)
plt.show()

# %% [markdown]
# # label parameter

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
plt.pie(x,labels=y)
plt.show()

# %% [markdown]
# # explode parameter

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
plt.pie(x,labels=y,explode=ex)
plt.show()

# %% [markdown]
# # color parameter

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c)
plt.show()

# %% [markdown]
# # percentage parameter

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%")
plt.show()

# %% [markdown]
# # shadow parameter

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True)
plt.show()

# %% [markdown]
# # increse redius

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.4)
plt.show()

# %% [markdown]
# # label distance far and near

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.4,labeldistance=1.1)
plt.show()

# %% [markdown]
# # pic graph rotation

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.4,labeldistance=1.1,startangle=360)
plt.show()

# %% [markdown]
# # fontsize change

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.4,labeldistance=1.1,startangle=360,textprops={"fontsize":17})
plt.show()

# %% [markdown]
# # pic graph clockwise and anticlockwise rotation change

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.4,labeldistance=1.1,startangle=360,textprops={"fontsize":17},counterclock=False)
plt.show()

# %% [markdown]
# # pie garaph edge change and width increse

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.4,labeldistance=1.1,startangle=0,textprops={"fontsize":17},counterclock=False,wedgeprops={"linewidth":4,"width":2})
plt.show()

# %% [markdown]
# # edge color and centre parameter

# %%
import matplotlib .pyplot as plt
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.4,labeldistance=1.1,startangle=0,textprops={"fontsize":17},counterclock=False,wedgeprops={"linewidth":4,"edgecolor":"m"},center=(0,0))
plt.show()

# %% [markdown]
# # label rotation

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.4,labeldistance=1.1,startangle=0,textprops={"fontsize":17},counterclock=False,wedgeprops={"linewidth":4},rotatelabels=True)
plt.show()

# %% [markdown]
# # title and legend parameter

# %%
x=[10,20,30,40]
y=["c","c++","java","python"]
ex=[0.2,0.0,0.0,0.0]
c=["r","g","y","b"]
plt.pie(x,labels=y,explode=ex,colors=c,autopct="%0.2f%%",shadow=True,radius=1.2,labeldistance=1.1,startangle=0,textprops={"fontsize":17},counterclock=False,wedgeprops={"linewidth":4},rotatelabels=True)
plt.title("nikhil",fontsize=20)
plt.legend(loc=3)
plt.show()

# %% [markdown]
# # dot pie

# %%
plt.pie([1])
plt.show()

# %% [markdown]
# # multiple dot pie chart making

# %%
x=[10,20,30,40]
x1=[40,30,20,10]
y=["c","c++","java","python"]
c=["g","b","g","y"]
plt.pie(x,labels=y,radius=1.5)
plt.pie(x1,radius=1,colors=c)
plt.show()

# %% [markdown]
# # ring pie chart

# %%
x=[10,20,30,40]
x1=[40,30,20,10]
y=["c","c++","java","python"]
c=["g","b","g","y"]
plt.pie(x,labels=y,radius=1.5)
plt.pie([1],colors="w")
plt.show()

# %%
import matplotlib.pyplot as plt
x=[10,20,30,40]
x1=[40,30,20,10]
y=["c","c++","java","python"]
c=["g","b","g","pink"]
plt.pie(x,labels=y,radius=1.5)
cr=plt.Circle(xy=(0,0),radius=1,facecolor="w")
plt.gca().add_artist(cr)
plt.show()

# %% [markdown]
# # ep8 stem plot

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
y=[2,2,5,7,3,3]
plt.stem(x,y)
plt.show()

# %% [markdown]
# # pass line

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,7,3,3]
plt.stem(x,y,linefmt=":")
plt.show()

# %% [markdown]
# # change the marker and symbol

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,7,3,3]
plt.stem(x,y,linefmt=":",markerfmt="r+")
plt.show()

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,7,3,3]
plt.stem(x,y,linefmt=":",markerfmt="ro")
plt.show()

# %% [markdown]
# # bottom parameter

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,7,3,3]
plt.stem(x,y,linefmt=":",markerfmt="r+",bottom=0)
plt.show()

# %% [markdown]
# # change of base color

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,7,3,3]
plt.stem(x,y,linefmt=":",markerfmt="r+",bottom=0,basefmt="black")
plt.show()

# %% [markdown]
# # label parameter

# %%
x=[1,2,3,4,5,6]
y=[2,2,5,7,3,3]
plt.stem(x,y,linefmt=":",markerfmt="r+",bottom=0,basefmt="black",label="python",use_line_collection=True)
plt.legend()
plt.show()

# %% [markdown]
# # bar plot

# %%
import matplotlib .pyplot as plt
x=[10,20,30,40,50,60]
plt.boxplot(x)
plt.show()

# %% [markdown]
# # change of box shape

# %%
import matplotlib .pyplot as plt
x=[10,20,30,40,50,60]
plt.boxplot(x,notch=False)
plt.show()

# %% [markdown]
# # width increse parameter

# %%
import matplotlib .pyplot as plt
x=[10,20,30,40,50,60,70,120]

plt.boxplot(x,widths=.2,labels=["python"],patch_artist=True,showmeans=True)
plt.show()

# %% [markdown]
# # whis parameter

# %%
import matplotlib .pyplot as plt
x=[10,20,30,40,50,60,70,120]
y=[12,23,46,78,90,100,190,199]
plt.boxplot(x,widths=.2,labels=["python"],patch_artist=True,showmeans=True,whis=23)
plt.show()

# %% [markdown]
# # the change the colour in outer line

# %%
import matplotlib .pyplot as plt
x=[10,20,30,40,50,60,70,120]
y=[12,23,46,78,90,100,190,199]
plt.boxplot(x,widths=.2,labels=["python"],patch_artist=True,showmeans=True,whis=23,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),wiskerprops=dict(color="r"),flierprops=dict(markeredgecolour="y"))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 4>()
#       2 x=[10,20,30,40,50,60,70,120]
#       3 y=[12,23,46,78,90,100,190,199]
# ----> 4 plt.boxplot(x,widths=.2,labels=["python"],patch_artist=True,showmeans=True,whis=23,sym="g+",boxprops=dict(color="r"),capprops=dict(color="r"),wiskerprops=dict(color="r"),flierprops=dict(markeredgecolour="y"))
#       5 plt.show()
#
# TypeError: boxplot() got an unexpected keyword argument 'wiskerprops'

# %% [markdown]
# # ep10 stack plot

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6]
area1=[5,2,6,4,7,9]
plt.stackplot(x,area1)
plt.show()

# %% [markdown]
# # multi stack plot

# %%
x=[1,2,3,4,5,6]
area1=[5,2,6,4,7,9]
area2=[4,6,8,9,10,15]
area3=[5,7,3,9,12,17]
plt.stackplot(x,area1,area2,area3)
plt.show()

# %% [markdown]
# # label and taking colour

# %%
x=[1,2,3,4,5,6]
area1=[5,2,6,4,7,9]
area2=[4,6,8,9,10,15]
area3=[5,7,3,9,12,17]
l=["area1","area2","area3"]
plt.stackplot(x,area1,area2,area3,labels=l,colors=["r","g","y"])
plt.legend(loc=2)
plt.show()

# %% [markdown]
# # taking baseline parameter

# %%
x=[1,2,3,4,5,6]
area1=[5,2,6,4,7,9]
area2=[4,6,8,9,10,15]
area3=[5,7,3,9,12,17]
plt.stackplot(x,area1,area2,area3,baseline="wiggle")
plt.show()

# %% [markdown]
# # ep10 step slot

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[4,5,6,7,8]
plt.step(x,y)
plt.show()

# %% [markdown]
# # grid

# %%
x=[1,2,3,4,5]
y=[4,5,6,7,8]
plt.step(x,y)
plt.grid()
plt.show()

# %% [markdown]
# # title parameter

# %%
x=[1,2,3,4,5]
y=[4,5,6,7,8]
plt.step(x,y)
plt.title("python")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# # use in marker

# %%
x=[1,2,3,4,5]
y=[4,5,6,7,8]
plt.step(x,y,color="b",marker="*",ms=11,label="python",mfc="g")
plt.title("python",fontsize=12)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(loc=2)
plt.show()
